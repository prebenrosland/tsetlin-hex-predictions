# %%
import argparse
import numpy as np
import pandas as pd
from time import time
from GraphTsetlinMachine.graphs import Graphs
from GraphTsetlinMachine.tm import MultiClassGraphTsetlinMachine

clauses=4000

def default_args(**kwargs):
    parser = argparse.ArgumentParser()
    parser.add_argument("--epochs", default=1000, type=int)
    parser.add_argument("--number-of-clauses", default=clauses, type=int)
    #parser.add_argument("--number-of-state-bits", default=8, type=int)
    parser.add_argument("--T", default=clauses/1.6, type=int)
    parser.add_argument("--s", default=1.15, type=float)
    parser.add_argument("--depth", default=1, type=int)
    parser.add_argument("--hypervector-size", default=512, type=int)
    parser.add_argument("--hypervector-bits", default=2, type=int)
    parser.add_argument("--message-size", default=512, type=int)
    parser.add_argument("--message-bits", default=2, type=int)
    parser.add_argument('--double-hashing', dest='double_hashing', default=True, action='store_true')
    parser.add_argument("--number-of-examples", default=100000, type=int)
    parser.add_argument("--max-included-literals", default=64, type=int)

    args, unknown = parser.parse_known_args()
    for key, value in kwargs.items():
        if key in args.__dict__:
            setattr(args, key, value)
    return args

args = default_args()

# %%
dataset = pd.read_csv('8x8_2bf.csv')
dataset = dataset.head(args.number_of_examples)

board_size = 8

split_ratio = 0.9
split_index = int(len(dataset) * split_ratio)
train_dataset = dataset.iloc[:split_index]
test_dataset = dataset.iloc[split_index:]

X_train_board = train_dataset['board'].values
Y_train = train_dataset['winner'].values.astype(np.uint32)
X_test_board = test_dataset['board'].values
Y_test = test_dataset['winner'].values.astype(np.uint32)

cell_value_mapping = {
    0: 'Empty',
    1: 'Red',
    2: 'Blue'
}

edge_type_mapping = {
    0: 'Plain',
    1: 'Red',
    2: 'Blue',
    3: 'Corner'
}

def parse_board(board_string):
    game_state = {}
    board_string = board_string.replace(' ', '')
    for idx, symbol in enumerate(board_string):
        i = idx // board_size
        j = idx % board_size
        node_id = i * board_size + j
        if symbol == 'X':
            cell_value = 1
        elif symbol == 'O':
            cell_value = 2
        else:
            cell_value = 0
        game_state[node_id] = cell_value
    return game_state

train_games = [parse_board(board_string) for board_string in X_train_board]
test_games = [parse_board(board_string) for board_string in X_test_board]

train_graph_length = len(train_games)
test_graph_length = len(test_games)

edges = {}
for i in range(board_size):
    for j in range(board_size):
        node = (i, j)
        edges[node] = []

def addedge(node1, node2):
    if node2 not in edges[node1]:
        edges[node1].append(node2)

for i in range(board_size):
    for j in range(board_size):
        node = (i, j)

        if i < board_size - 1:
            addedge(node, (i + 1, j))
            addedge((i + 1, j), node)

            if j > 0:
                addedge(node, (i + 1, j - 1))
                addedge((i + 1, j - 1), node)

        if j < board_size - 1:
            addedge(node, (i, j + 1))
            addedge((i, j + 1), node)

        if i > 0:
            addedge(node, (i - 1, j))
            addedge((i - 1, j), node)

        if j > 0:
            addedge(node, (i, j - 1))
            addedge((i, j - 1), node)

node_indices = {}
index = 0
for i in range(board_size):
    for j in range(board_size):
        node = (i, j)
        node_indices[node] = index
        index += 1

# %%
print('Creating training data')

graphs_train = Graphs(
    train_graph_length,
    symbols=['Empty', 'Red', 'Blue', '1', '2', '3', '4', '5', 'connected',
             'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8',
             'r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7','r8'],
    hypervector_size=args.hypervector_size,
    hypervector_bits=args.hypervector_bits,
)

for graph_id in range(train_graph_length):
    graphs_train.set_number_of_graph_nodes(graph_id, board_size ** 2)

graphs_train.prepare_node_configuration()

for graph_id in range(train_graph_length):
    for i in range(board_size):
        for j in range(board_size):
            node_id = i * board_size + j
            node = (i, j)
            number_of_outgoing_edges = len(edges[node])
            graphs_train.add_graph_node(graph_id, node_id, number_of_outgoing_edges)

graphs_train.prepare_edge_configuration()

for graph_id in range(train_graph_length):
    game = train_games[graph_id]
    if graph_id % 10000 == 0:
        print('Adding edges for graph id:', graph_id)
    for i in range(board_size):
        for j in range(board_size):
            node_id = i * board_size + j
            node = (i, j)
            cell_value = game.get(node_id, 0)
            edge_type = edge_type_mapping[0]

            for neighbor in edges[node]:
                neighbor_i, neighbor_j = neighbor
                neighbor_id = neighbor_i * board_size + neighbor_j
                cell_neighbor = game.get(neighbor_id, 0)
                if cell_value == cell_neighbor and cell_value != 0:
                    edge_type_value = edge_type_mapping.get(cell_value, 'Plain')
                    graphs_train.add_graph_node_edge(graph_id, node_id, neighbor_id, edge_type_value)
                else:
                    graphs_train.add_graph_node_edge(graph_id, node_id, neighbor_id, edge_type)

Y_train_labels = np.empty(train_graph_length, dtype=np.uint32)

for graph_id in range(train_graph_length):
    game = train_games[graph_id]
    Y_train_labels[graph_id] = Y_train[graph_id]

    if graph_id % 10000 == 0:
        print('Adding properties for graph id:', graph_id)

    for i in range(board_size):
        for j in range(board_size):
            node_id = i * board_size + j
            node = (i, j)
            cell_value = game.get(node_id, 0)
            cell_property = cell_value_mapping.get(cell_value)
            graphs_train.add_graph_node_property(graph_id, node_id, cell_property)

            num_neigh = 0
            for neighbor in edges[node]:
                neighbor_i, neighbor_j = neighbor
                neighbor_id = neighbor_i * board_size + neighbor_j
                cell_neighbor = game.get(neighbor_id, 0)
                if cell_value == cell_neighbor and cell_value != 0:
                    num_neigh += 1
            if num_neigh > 1:
                graphs_train.add_graph_node_property(graph_id, node_id, "connected")

            graphs_train.add_graph_node_property(graph_id, node_id, f"c{i+1}")
            graphs_train.add_graph_node_property(graph_id, node_id, f"r{j+1}")

graphs_train.encode()
# Out:
# Creating training data
# Adding edges for graph id: 0
# Adding edges for graph id: 10000
# Adding edges for graph id: 20000
# Adding edges for graph id: 30000
# Adding edges for graph id: 40000
# Adding edges for graph id: 50000
# Adding edges for graph id: 60000
# Adding edges for graph id: 70000
# Adding edges for graph id: 80000
# Adding properties for graph id: 0
# Adding properties for graph id: 10000
# Adding properties for graph id: 20000
# Adding properties for graph id: 30000
# Adding properties for graph id: 40000
# Adding properties for graph id: 50000
# Adding properties for graph id: 60000
# Adding properties for graph id: 70000
# Adding properties for graph id: 80000

# %%
# Test graph
print("Creating test data")
graphs_test = Graphs(test_graph_length, init_with=graphs_train)

for graph_id in range(test_graph_length):
    graphs_test.set_number_of_graph_nodes(graph_id, board_size ** 2)

graphs_test.prepare_node_configuration()

for graph_id in range(test_graph_length):
    for i in range(board_size):
        for j in range(board_size):
            node_id = i * board_size + j
            node = (i, j)
            number_of_outgoing_edges = len(edges[node])
            graphs_test.add_graph_node(graph_id, node_id, number_of_outgoing_edges)

graphs_test.prepare_edge_configuration()

for graph_id in range(test_graph_length):
    game = test_games[graph_id]
    if graph_id % 1000 == 0:
        print('Adding edges for graph id:', graph_id)
    for i in range(board_size):
        for j in range(board_size):
            node_id = i * board_size + j
            node = (i, j)
            cell_value = game.get(node_id, 0)
            edge_type = edge_type_mapping[0]

            for neighbor in edges[node]:
                neighbor_i, neighbor_j = neighbor
                neighbor_id = neighbor_i * board_size + neighbor_j
                cell_neighbor = game.get(neighbor_id, 0)
                if cell_value == cell_neighbor and cell_value != 0:
                    edge_type_value = edge_type_mapping.get(cell_value, 'Plain')
                    graphs_test.add_graph_node_edge(graph_id, node_id, neighbor_id, edge_type_value)
                else:
                    graphs_test.add_graph_node_edge(graph_id, node_id, neighbor_id, edge_type)

Y_test_labels = np.empty(test_graph_length, dtype=np.uint32)

for graph_id in range(test_graph_length):
    game = test_games[graph_id]
    Y_test_labels[graph_id] = Y_test[graph_id]

    if graph_id % 1000 == 0:
        print('Adding properties for graph id:', graph_id)

    for i in range(board_size):
        for j in range(board_size):
            node_id = i * board_size + j
            node = (i, j)
            cell_value = game.get(node_id, 0)
            cell_property = cell_value_mapping.get(cell_value)
            graphs_test.add_graph_node_property(graph_id, node_id, cell_property)

            num_neigh = 0
            for neighbor in edges[node]:
                neighbor_i, neighbor_j = neighbor
                neighbor_id = neighbor_i * board_size + neighbor_j
                cell_neighbor = game.get(neighbor_id, 0)
                if cell_value == cell_neighbor and cell_value != 0:
                    num_neigh += 1
            if num_neigh > 1:
                graphs_test.add_graph_node_property(graph_id, node_id, "connected")

            graphs_test.add_graph_node_property(graph_id, node_id, f"c{i+1}")
            graphs_test.add_graph_node_property(graph_id, node_id, f"r{j+1}")

graphs_test.encode()
# Out:
# Creating test data
# Adding edges for graph id: 0
# Adding edges for graph id: 1000
# Adding edges for graph id: 2000
# Adding edges for graph id: 3000
# Adding edges for graph id: 4000
# Adding edges for graph id: 5000
# Adding edges for graph id: 6000
# Adding edges for graph id: 7000
# Adding edges for graph id: 8000
# Adding edges for graph id: 9000
# Adding properties for graph id: 0
# Adding properties for graph id: 1000
# Adding properties for graph id: 2000
# Adding properties for graph id: 3000
# Adding properties for graph id: 4000
# Adding properties for graph id: 5000
# Adding properties for graph id: 6000
# Adding properties for graph id: 7000
# Adding properties for graph id: 8000
# Adding properties for graph id: 9000

# %%
train_acc = []
test_acc = []
epoch_list = []
epoch = 0


tm = MultiClassGraphTsetlinMachine(
    args.number_of_clauses,
    args.T,
    args.s,
    depth=args.depth,
    message_size=args.message_size,
    message_bits=args.message_bits,
    max_included_literals=args.max_included_literals,
    double_hashing = args.double_hashing,
    grid=(16*13,1,1),
    block=(128,1,1)
)

for i in range(args.epochs):
    epoch+=1
    start_training = time()
    tm.fit(graphs_train, Y_train, epochs=1, incremental=True)
    stop_training = time()

    start_testing = time()
    result_test = 100*(tm.predict(graphs_test) == Y_test).mean()
    stop_testing = time()

    result_train = 100*(tm.predict(graphs_train) == Y_train).mean()

    train_acc.append(result_train)
    test_acc.append(result_test)
    epoch_list.append(epoch)

    print(f"Epoch: {i}, Train acc: {result_train:.2f}, Test acc: {result_test:.2f}, Epoch time: {stop_testing-start_training:.2f}")

weights = tm.get_state()[1].reshape(2, -1)

print(graphs_test.hypervectors)
print(tm.hypervectors)
print(graphs_test.edge_type_id)
# Out:
# Initialization of sparse structure.
# Epoch: 0, Train acc: 96.45, Test acc: 96.34, Epoch time: 30.03
# Epoch: 1, Train acc: 96.87, Test acc: 96.74, Epoch time: 23.13
# Epoch: 2, Train acc: 99.37, Test acc: 99.18, Epoch time: 21.57
# Epoch: 3, Train acc: 99.56, Test acc: 99.41, Epoch time: 20.87
# Epoch: 4, Train acc: 99.22, Test acc: 99.28, Epoch time: 20.33
# Epoch: 5, Train acc: 99.60, Test acc: 99.44, Epoch time: 19.81
# Epoch: 6, Train acc: 99.45, Test acc: 99.40, Epoch time: 19.53
# Epoch: 7, Train acc: 98.87, Test acc: 98.74, Epoch time: 19.28
# Epoch: 8, Train acc: 99.60, Test acc: 99.57, Epoch time: 19.06
# Epoch: 9, Train acc: 99.57, Test acc: 99.56, Epoch time: 18.91
# Epoch: 10, Train acc: 99.55, Test acc: 99.52, Epoch time: 18.78
# Epoch: 11, Train acc: 96.75, Test acc: 96.31, Epoch time: 19.36
# Epoch: 12, Train acc: 98.50, Test acc: 98.23, Epoch time: 19.43
# Epoch: 13, Train acc: 99.22, Test acc: 99.10, Epoch time: 18.87
# Epoch: 14, Train acc: 99.46, Test acc: 99.42, Epoch time: 18.73
# Epoch: 15, Train acc: 99.20, Test acc: 99.19, Epoch time: 18.87
# Epoch: 16, Train acc: 99.54, Test acc: 99.56, Epoch time: 18.55
# Epoch: 17, Train acc: 99.45, Test acc: 99.40, Epoch time: 18.49
# Epoch: 18, Train acc: 99.91, Test acc: 99.81, Epoch time: 18.49
# Epoch: 19, Train acc: 99.80, Test acc: 99.72, Epoch time: 18.36
# Epoch: 20, Train acc: 99.62, Test acc: 99.61, Epoch time: 18.34
# Epoch: 21, Train acc: 99.86, Test acc: 99.79, Epoch time: 18.35
# Epoch: 22, Train acc: 99.85, Test acc: 99.69, Epoch time: 18.21
# Epoch: 23, Train acc: 99.94, Test acc: 99.87, Epoch time: 18.12
# Epoch: 24, Train acc: 99.88, Test acc: 99.78, Epoch time: 18.12
# Epoch: 25, Train acc: 99.94, Test acc: 99.87, Epoch time: 18.09
# Epoch: 26, Train acc: 99.90, Test acc: 99.85, Epoch time: 18.10
# Epoch: 27, Train acc: 99.93, Test acc: 99.84, Epoch time: 18.10
# Epoch: 28, Train acc: 98.76, Test acc: 98.68, Epoch time: 20.67
# Epoch: 29, Train acc: 99.83, Test acc: 99.73, Epoch time: 18.79
# Epoch: 30, Train acc: 99.13, Test acc: 99.18, Epoch time: 18.57
# Epoch: 31, Train acc: 99.84, Test acc: 99.81, Epoch time: 18.43
# Epoch: 32, Train acc: 99.48, Test acc: 99.42, Epoch time: 18.39
# Epoch: 33, Train acc: 99.78, Test acc: 99.79, Epoch time: 18.39
# Epoch: 34, Train acc: 99.92, Test acc: 99.81, Epoch time: 18.33
# Epoch: 35, Train acc: 99.92, Test acc: 99.87, Epoch time: 18.26
# Epoch: 36, Train acc: 99.86, Test acc: 99.88, Epoch time: 18.18
# Epoch: 37, Train acc: 99.77, Test acc: 99.64, Epoch time: 18.20
# Epoch: 38, Train acc: 75.04, Test acc: 74.62, Epoch time: 18.25
# Epoch: 39, Train acc: 99.92, Test acc: 99.87, Epoch time: 19.39
# Epoch: 40, Train acc: 99.91, Test acc: 99.88, Epoch time: 18.38
# Epoch: 41, Train acc: 99.94, Test acc: 99.82, Epoch time: 18.31
# Epoch: 42, Train acc: 98.89, Test acc: 98.92, Epoch time: 18.18
# Epoch: 43, Train acc: 99.86, Test acc: 99.74, Epoch time: 18.20
# Epoch: 44, Train acc: 99.96, Test acc: 99.90, Epoch time: 18.12
# Epoch: 45, Train acc: 99.93, Test acc: 99.87, Epoch time: 18.93
# Epoch: 46, Train acc: 99.92, Test acc: 99.87, Epoch time: 18.26
# Epoch: 47, Train acc: 99.71, Test acc: 99.61, Epoch time: 18.16
# Epoch: 48, Train acc: 99.90, Test acc: 99.84, Epoch time: 18.09
# Epoch: 49, Train acc: 99.82, Test acc: 99.69, Epoch time: 18.07
# Epoch: 50, Train acc: 99.96, Test acc: 99.89, Epoch time: 18.03
# Epoch: 51, Train acc: 99.96, Test acc: 99.88, Epoch time: 17.99
# Epoch: 52, Train acc: 99.84, Test acc: 99.74, Epoch time: 17.94
# Epoch: 53, Train acc: 99.97, Test acc: 99.94, Epoch time: 17.95
# Epoch: 54, Train acc: 99.96, Test acc: 99.87, Epoch time: 17.89
# Epoch: 55, Train acc: 99.89, Test acc: 99.83, Epoch time: 17.86
# Epoch: 56, Train acc: 99.95, Test acc: 99.92, Epoch time: 17.85
# Epoch: 57, Train acc: 99.64, Test acc: 99.54, Epoch time: 17.85
# Epoch: 58, Train acc: 99.91, Test acc: 99.82, Epoch time: 17.87
# Epoch: 59, Train acc: 99.90, Test acc: 99.82, Epoch time: 17.80
# Epoch: 60, Train acc: 99.90, Test acc: 99.83, Epoch time: 17.79
# Epoch: 61, Train acc: 99.90, Test acc: 99.80, Epoch time: 17.81
# Epoch: 62, Train acc: 98.41, Test acc: 98.49, Epoch time: 17.78
# Epoch: 63, Train acc: 98.43, Test acc: 98.42, Epoch time: 17.77
# Epoch: 64, Train acc: 99.41, Test acc: 99.35, Epoch time: 17.75
# Epoch: 65, Train acc: 99.97, Test acc: 99.94, Epoch time: 17.74
# Epoch: 66, Train acc: 99.97, Test acc: 99.90, Epoch time: 17.77
# Epoch: 67, Train acc: 99.75, Test acc: 99.71, Epoch time: 17.72
# Epoch: 68, Train acc: 99.70, Test acc: 99.60, Epoch time: 17.74
# Epoch: 69, Train acc: 99.72, Test acc: 99.74, Epoch time: 18.93
# Epoch: 70, Train acc: 99.20, Test acc: 99.34, Epoch time: 18.38
# Epoch: 71, Train acc: 99.61, Test acc: 99.56, Epoch time: 18.15
# Epoch: 72, Train acc: 99.34, Test acc: 99.25, Epoch time: 18.00
# Epoch: 73, Train acc: 99.97, Test acc: 99.92, Epoch time: 17.95
# Epoch: 74, Train acc: 99.78, Test acc: 99.70, Epoch time: 17.85
# Epoch: 75, Train acc: 99.87, Test acc: 99.76, Epoch time: 17.81
# Epoch: 76, Train acc: 99.87, Test acc: 99.76, Epoch time: 17.81
# Epoch: 77, Train acc: 98.40, Test acc: 98.51, Epoch time: 17.80
# Epoch: 78, Train acc: 99.36, Test acc: 99.26, Epoch time: 17.74
# Epoch: 79, Train acc: 99.95, Test acc: 99.87, Epoch time: 17.75
# Epoch: 80, Train acc: 99.90, Test acc: 99.84, Epoch time: 17.69
# Epoch: 81, Train acc: 99.97, Test acc: 99.89, Epoch time: 17.70
# Epoch: 82, Train acc: 99.33, Test acc: 99.27, Epoch time: 17.73
# Epoch: 83, Train acc: 99.88, Test acc: 99.81, Epoch time: 17.72
# Epoch: 84, Train acc: 99.16, Test acc: 99.13, Epoch time: 17.71
# Epoch: 85, Train acc: 99.92, Test acc: 99.87, Epoch time: 17.71
# Epoch: 86, Train acc: 99.99, Test acc: 99.94, Epoch time: 17.66
# Epoch: 87, Train acc: 99.90, Test acc: 99.83, Epoch time: 17.64
# Epoch: 88, Train acc: 99.97, Test acc: 99.89, Epoch time: 17.67
# Epoch: 89, Train acc: 99.99, Test acc: 99.93, Epoch time: 17.66
# Epoch: 90, Train acc: 99.99, Test acc: 99.94, Epoch time: 17.69
# Epoch: 91, Train acc: 99.83, Test acc: 99.69, Epoch time: 17.66
# Epoch: 92, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.67
# Epoch: 93, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.64
# Epoch: 94, Train acc: 99.82, Test acc: 99.77, Epoch time: 17.64
# Epoch: 95, Train acc: 99.90, Test acc: 99.85, Epoch time: 17.63
# Epoch: 96, Train acc: 99.98, Test acc: 99.97, Epoch time: 17.67
# Epoch: 97, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.68
# Epoch: 98, Train acc: 99.80, Test acc: 99.73, Epoch time: 17.69
# Epoch: 99, Train acc: 99.65, Test acc: 99.58, Epoch time: 17.67
# Epoch: 100, Train acc: 99.99, Test acc: 99.99, Epoch time: 17.69
# Epoch: 101, Train acc: 99.98, Test acc: 99.96, Epoch time: 17.63
# Epoch: 102, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.61
# Epoch: 103, Train acc: 99.92, Test acc: 99.82, Epoch time: 17.60
# Epoch: 104, Train acc: 99.90, Test acc: 99.85, Epoch time: 17.64
# Epoch: 105, Train acc: 99.98, Test acc: 99.95, Epoch time: 17.63
# Epoch: 106, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.62
# Epoch: 107, Train acc: 99.98, Test acc: 99.97, Epoch time: 17.62
# Epoch: 108, Train acc: 99.96, Test acc: 99.92, Epoch time: 17.61
# Epoch: 109, Train acc: 99.96, Test acc: 99.93, Epoch time: 17.58
# Epoch: 110, Train acc: 97.98, Test acc: 98.01, Epoch time: 17.55
# Epoch: 111, Train acc: 99.98, Test acc: 99.98, Epoch time: 17.59
# Epoch: 112, Train acc: 99.59, Test acc: 99.59, Epoch time: 17.57
# Epoch: 113, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.56
# Epoch: 114, Train acc: 99.97, Test acc: 99.95, Epoch time: 17.55
# Epoch: 115, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.53
# Epoch: 116, Train acc: 99.93, Test acc: 99.88, Epoch time: 17.52
# Epoch: 117, Train acc: 99.97, Test acc: 99.94, Epoch time: 17.55
# Epoch: 118, Train acc: 99.79, Test acc: 99.69, Epoch time: 17.54
# Epoch: 119, Train acc: 99.98, Test acc: 99.93, Epoch time: 17.54
# Epoch: 120, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.56
# Epoch: 121, Train acc: 99.99, Test acc: 99.94, Epoch time: 17.53
# Epoch: 122, Train acc: 99.91, Test acc: 99.86, Epoch time: 17.52
# Epoch: 123, Train acc: 99.98, Test acc: 99.94, Epoch time: 17.53
# Epoch: 124, Train acc: 99.98, Test acc: 99.97, Epoch time: 17.53
# Epoch: 125, Train acc: 99.85, Test acc: 99.81, Epoch time: 17.53
# Epoch: 126, Train acc: 98.99, Test acc: 98.94, Epoch time: 17.54
# Epoch: 127, Train acc: 99.98, Test acc: 99.95, Epoch time: 17.55
# Epoch: 128, Train acc: 99.92, Test acc: 99.90, Epoch time: 17.57
# Epoch: 129, Train acc: 93.83, Test acc: 93.45, Epoch time: 17.65
# Epoch: 130, Train acc: 99.95, Test acc: 99.85, Epoch time: 19.48
# Epoch: 131, Train acc: 99.83, Test acc: 99.86, Epoch time: 17.76
# Epoch: 132, Train acc: 99.66, Test acc: 99.64, Epoch time: 17.50
# Epoch: 133, Train acc: 99.94, Test acc: 99.86, Epoch time: 17.40
# Epoch: 134, Train acc: 99.93, Test acc: 99.87, Epoch time: 17.34
# Epoch: 135, Train acc: 98.70, Test acc: 98.78, Epoch time: 17.36
# Epoch: 136, Train acc: 99.64, Test acc: 99.62, Epoch time: 17.33
# Epoch: 137, Train acc: 99.76, Test acc: 99.69, Epoch time: 17.29
# Epoch: 138, Train acc: 99.96, Test acc: 99.89, Epoch time: 17.24
# Epoch: 139, Train acc: 99.93, Test acc: 99.88, Epoch time: 17.27
# Epoch: 140, Train acc: 99.95, Test acc: 99.89, Epoch time: 17.27
# Epoch: 141, Train acc: 99.92, Test acc: 99.83, Epoch time: 17.23
# Epoch: 142, Train acc: 99.82, Test acc: 99.84, Epoch time: 17.24
# Epoch: 143, Train acc: 99.85, Test acc: 99.77, Epoch time: 17.26
# Epoch: 144, Train acc: 99.94, Test acc: 99.90, Epoch time: 17.92
# Epoch: 145, Train acc: 99.95, Test acc: 99.89, Epoch time: 17.75
# Epoch: 146, Train acc: 99.95, Test acc: 99.85, Epoch time: 17.49
# Epoch: 147, Train acc: 99.62, Test acc: 99.57, Epoch time: 17.39
# Epoch: 148, Train acc: 99.81, Test acc: 99.73, Epoch time: 17.34
# Epoch: 149, Train acc: 99.97, Test acc: 99.92, Epoch time: 17.34
# Epoch: 150, Train acc: 99.96, Test acc: 99.90, Epoch time: 17.35
# Epoch: 151, Train acc: 99.99, Test acc: 99.93, Epoch time: 17.32
# Epoch: 152, Train acc: 99.60, Test acc: 99.50, Epoch time: 17.23
# Epoch: 153, Train acc: 99.88, Test acc: 99.81, Epoch time: 17.29
# Epoch: 154, Train acc: 99.97, Test acc: 99.93, Epoch time: 17.25
# Epoch: 155, Train acc: 99.89, Test acc: 99.82, Epoch time: 17.24
# Epoch: 156, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.21
# Epoch: 157, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.17
# Epoch: 158, Train acc: 99.99, Test acc: 99.93, Epoch time: 17.21
# Epoch: 159, Train acc: 99.96, Test acc: 99.93, Epoch time: 17.19
# Epoch: 160, Train acc: 99.77, Test acc: 99.72, Epoch time: 17.16
# Epoch: 161, Train acc: 99.99, Test acc: 99.92, Epoch time: 17.17
# Epoch: 162, Train acc: 99.96, Test acc: 99.89, Epoch time: 17.17
# Epoch: 163, Train acc: 99.99, Test acc: 99.94, Epoch time: 17.14
# Epoch: 164, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.15
# Epoch: 165, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.12
# Epoch: 166, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.14
# Epoch: 167, Train acc: 99.91, Test acc: 99.88, Epoch time: 17.13
# Epoch: 168, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.15
# Epoch: 169, Train acc: 99.94, Test acc: 99.87, Epoch time: 17.10
# Epoch: 170, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.15
# Epoch: 171, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.12
# Epoch: 172, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.11
# Epoch: 173, Train acc: 99.99, Test acc: 99.94, Epoch time: 17.10
# Epoch: 174, Train acc: 99.55, Test acc: 99.37, Epoch time: 17.56
# Epoch: 175, Train acc: 99.97, Test acc: 99.91, Epoch time: 17.73
# Epoch: 176, Train acc: 99.95, Test acc: 99.95, Epoch time: 17.38
# Epoch: 177, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.35
# Epoch: 178, Train acc: 99.97, Test acc: 99.95, Epoch time: 17.69
# Epoch: 179, Train acc: 99.77, Test acc: 99.69, Epoch time: 17.41
# Epoch: 180, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.24
# Epoch: 181, Train acc: 99.98, Test acc: 99.94, Epoch time: 17.20
# Epoch: 182, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.24
# Epoch: 183, Train acc: 99.96, Test acc: 99.94, Epoch time: 17.20
# Epoch: 184, Train acc: 99.99, Test acc: 99.94, Epoch time: 17.19
# Epoch: 185, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.17
# Epoch: 186, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.16
# Epoch: 187, Train acc: 99.98, Test acc: 99.96, Epoch time: 17.13
# Epoch: 188, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.17
# Epoch: 189, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.12
# Epoch: 190, Train acc: 99.98, Test acc: 99.94, Epoch time: 17.11
# Epoch: 191, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.11
# Epoch: 192, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.14
# Epoch: 193, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.11
# Epoch: 194, Train acc: 99.98, Test acc: 99.95, Epoch time: 17.10
# Epoch: 195, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.10
# Epoch: 196, Train acc: 99.98, Test acc: 99.97, Epoch time: 17.09
# Epoch: 197, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.15
# Epoch: 198, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.12
# Epoch: 199, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.13
# Epoch: 200, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.10
# Epoch: 201, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.09
# Epoch: 202, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.08
# Epoch: 203, Train acc: 99.97, Test acc: 99.92, Epoch time: 18.06
# Epoch: 204, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.38
# Epoch: 205, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.22
# Epoch: 206, Train acc: 99.97, Test acc: 99.95, Epoch time: 17.17
# Epoch: 207, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.18
# Epoch: 208, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.14
# Epoch: 209, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.15
# Epoch: 210, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.15
# Epoch: 211, Train acc: 99.91, Test acc: 99.89, Epoch time: 17.11
# Epoch: 212, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.10
# Epoch: 213, Train acc: 99.94, Test acc: 99.90, Epoch time: 17.10
# Epoch: 214, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.11
# Epoch: 215, Train acc: 99.97, Test acc: 99.92, Epoch time: 17.15
# Epoch: 216, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.11
# Epoch: 217, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.11
# Epoch: 218, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.11
# Epoch: 219, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.12
# Epoch: 220, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.13
# Epoch: 221, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.14
# Epoch: 222, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.12
# Epoch: 223, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.11
# Epoch: 224, Train acc: 99.98, Test acc: 99.93, Epoch time: 17.13
# Epoch: 225, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.11
# Epoch: 226, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.07
# Epoch: 227, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.09
# Epoch: 228, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.10
# Epoch: 229, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.10
# Epoch: 230, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.13
# Epoch: 231, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.07
# Epoch: 232, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.09
# Epoch: 233, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.08
# Epoch: 234, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.09
# Epoch: 235, Train acc: 99.92, Test acc: 99.88, Epoch time: 17.09
# Epoch: 236, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.07
# Epoch: 237, Train acc: 99.99, Test acc: 99.94, Epoch time: 17.11
# Epoch: 238, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.07
# Epoch: 239, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.11
# Epoch: 240, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.08
# Epoch: 241, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.05
# Epoch: 242, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.05
# Epoch: 243, Train acc: 99.98, Test acc: 99.94, Epoch time: 17.05
# Epoch: 244, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.09
# Epoch: 245, Train acc: 99.98, Test acc: 99.96, Epoch time: 17.06
# Epoch: 246, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.05
# Epoch: 247, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.03
# Epoch: 248, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.06
# Epoch: 249, Train acc: 99.99, Test acc: 99.94, Epoch time: 17.03
# Epoch: 250, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.04
# Epoch: 251, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.01
# Epoch: 252, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.03
# Epoch: 253, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.02
# Epoch: 254, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.04
# Epoch: 255, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.07
# Epoch: 256, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.06
# Epoch: 257, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.06
# Epoch: 258, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.03
# Epoch: 259, Train acc: 99.48, Test acc: 99.43, Epoch time: 18.39
# Epoch: 260, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.54
# Epoch: 261, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.24
# Epoch: 262, Train acc: 99.91, Test acc: 99.90, Epoch time: 17.19
# Epoch: 263, Train acc: 99.92, Test acc: 99.86, Epoch time: 17.16
# Epoch: 264, Train acc: 99.82, Test acc: 99.77, Epoch time: 17.14
# Epoch: 265, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.13
# Epoch: 266, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.14
# Epoch: 267, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.11
# Epoch: 268, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.06
# Epoch: 269, Train acc: 99.99, Test acc: 99.99, Epoch time: 17.10
# Epoch: 270, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.07
# Epoch: 271, Train acc: 99.97, Test acc: 99.98, Epoch time: 17.07
# Epoch: 272, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.16
# Epoch: 273, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.10
# Epoch: 274, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.09
# Epoch: 275, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.07
# Epoch: 276, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.04
# Epoch: 277, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.08
# Epoch: 278, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.05
# Epoch: 279, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.07
# Epoch: 280, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.06
# Epoch: 281, Train acc: 99.25, Test acc: 99.24, Epoch time: 17.14
# Epoch: 282, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.13
# Epoch: 283, Train acc: 99.98, Test acc: 99.94, Epoch time: 17.09
# Epoch: 284, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.03
# Epoch: 285, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.06
# Epoch: 286, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.23
# Epoch: 287, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.12
# Epoch: 288, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.09
# Epoch: 289, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.04
# Epoch: 290, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.04
# Epoch: 291, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.03
# Epoch: 292, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.04
# Epoch: 293, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.06
# Epoch: 294, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.06
# Epoch: 295, Train acc: 99.97, Test acc: 99.95, Epoch time: 17.04
# Epoch: 296, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.08
# Epoch: 297, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.04
# Epoch: 298, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.03
# Epoch: 299, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.05
# Epoch: 300, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.02
# Epoch: 301, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.06
# Epoch: 302, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.04
# Epoch: 303, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.04
# Epoch: 304, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.04
# Epoch: 305, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.01
# Epoch: 306, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.03
# Epoch: 307, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.03
# Epoch: 308, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.03
# Epoch: 309, Train acc: 99.99, Test acc: 99.99, Epoch time: 17.03
# Epoch: 310, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.03
# Epoch: 311, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.04
# Epoch: 312, Train acc: 99.98, Test acc: 99.94, Epoch time: 17.03
# Epoch: 313, Train acc: 99.97, Test acc: 99.93, Epoch time: 17.05
# Epoch: 314, Train acc: 99.99, Test acc: 99.99, Epoch time: 17.07
# Epoch: 315, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.01
# Epoch: 316, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.04
# Epoch: 317, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.01
# Epoch: 318, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.05
# Epoch: 319, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.01
# Epoch: 320, Train acc: 99.99, Test acc: 99.99, Epoch time: 17.01
# Epoch: 321, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.02
# Epoch: 322, Train acc: 99.99, Test acc: 99.94, Epoch time: 16.99
# Epoch: 323, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.00
# Epoch: 324, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.02
# Epoch: 325, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.03
# Epoch: 326, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.03
# Epoch: 327, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 328, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.00
# Epoch: 329, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.02
# Epoch: 330, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.01
# Epoch: 331, Train acc: 99.75, Test acc: 99.77, Epoch time: 18.10
# Epoch: 332, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.53
# Epoch: 333, Train acc: 99.98, Test acc: 99.92, Epoch time: 17.41
# Epoch: 334, Train acc: 99.97, Test acc: 99.97, Epoch time: 17.26
# Epoch: 335, Train acc: 97.79, Test acc: 97.79, Epoch time: 17.18
# Epoch: 336, Train acc: 99.97, Test acc: 99.92, Epoch time: 17.17
# Epoch: 337, Train acc: 99.98, Test acc: 99.94, Epoch time: 17.10
# Epoch: 338, Train acc: 99.97, Test acc: 99.97, Epoch time: 17.05
# Epoch: 339, Train acc: 99.98, Test acc: 99.97, Epoch time: 17.03
# Epoch: 340, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.04
# Epoch: 341, Train acc: 99.97, Test acc: 99.96, Epoch time: 17.10
# Epoch: 342, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.06
# Epoch: 343, Train acc: 99.99, Test acc: 99.94, Epoch time: 17.06
# Epoch: 344, Train acc: 99.99, Test acc: 100.00, Epoch time: 17.05
# Epoch: 345, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.05
# Epoch: 346, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.05
# Epoch: 347, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.04
# Epoch: 348, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.04
# Epoch: 349, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.03
# Epoch: 350, Train acc: 99.98, Test acc: 99.99, Epoch time: 17.05
# Epoch: 351, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.03
# Epoch: 352, Train acc: 99.94, Test acc: 99.90, Epoch time: 17.02
# Epoch: 353, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.00
# Epoch: 354, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.00
# Epoch: 355, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.07
# Epoch: 356, Train acc: 99.91, Test acc: 99.88, Epoch time: 17.03
# Epoch: 357, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.00
# Epoch: 358, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 359, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.03
# Epoch: 360, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.99
# Epoch: 361, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.01
# Epoch: 362, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.03
# Epoch: 363, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.01
# Epoch: 364, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.00
# Epoch: 365, Train acc: 99.99, Test acc: 99.94, Epoch time: 17.00
# Epoch: 366, Train acc: 99.98, Test acc: 99.95, Epoch time: 16.99
# Epoch: 367, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 368, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.00
# Epoch: 369, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.99
# Epoch: 370, Train acc: 100.00, Test acc: 99.95, Epoch time: 16.98
# Epoch: 371, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.97
# Epoch: 372, Train acc: 99.98, Test acc: 99.93, Epoch time: 17.01
# Epoch: 373, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.00
# Epoch: 374, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.00
# Epoch: 375, Train acc: 99.99, Test acc: 99.93, Epoch time: 16.99
# Epoch: 376, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.00
# Epoch: 377, Train acc: 99.99, Test acc: 99.99, Epoch time: 17.00
# Epoch: 378, Train acc: 100.00, Test acc: 99.95, Epoch time: 16.98
# Epoch: 379, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 380, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.99
# Epoch: 381, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.01
# Epoch: 382, Train acc: 99.99, Test acc: 99.99, Epoch time: 16.99
# Epoch: 383, Train acc: 99.93, Test acc: 99.80, Epoch time: 18.10
# Epoch: 384, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.37
# Epoch: 385, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.17
# Epoch: 386, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.09
# Epoch: 387, Train acc: 99.99, Test acc: 99.94, Epoch time: 17.13
# Epoch: 388, Train acc: 99.98, Test acc: 99.92, Epoch time: 17.10
# Epoch: 389, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.07
# Epoch: 390, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.07
# Epoch: 391, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.03
# Epoch: 392, Train acc: 98.87, Test acc: 98.94, Epoch time: 17.06
# Epoch: 393, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.05
# Epoch: 394, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.05
# Epoch: 395, Train acc: 99.99, Test acc: 99.94, Epoch time: 17.04
# Epoch: 396, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.05
# Epoch: 397, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.03
# Epoch: 398, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.03
# Epoch: 399, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.03
# Epoch: 400, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.02
# Epoch: 401, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.02
# Epoch: 402, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.02
# Epoch: 403, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.02
# Epoch: 404, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.02
# Epoch: 405, Train acc: 99.97, Test acc: 99.92, Epoch time: 17.03
# Epoch: 406, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.00
# Epoch: 407, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.03
# Epoch: 408, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.97
# Epoch: 409, Train acc: 100.00, Test acc: 100.00, Epoch time: 16.99
# Epoch: 410, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.97
# Epoch: 411, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.00
# Epoch: 412, Train acc: 99.99, Test acc: 99.97, Epoch time: 16.98
# Epoch: 413, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.01
# Epoch: 414, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.01
# Epoch: 415, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.01
# Epoch: 416, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.01
# Epoch: 417, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.02
# Epoch: 418, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.00
# Epoch: 419, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.00
# Epoch: 420, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.99
# Epoch: 421, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.98
# Epoch: 422, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.00
# Epoch: 423, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.99
# Epoch: 424, Train acc: 99.99, Test acc: 99.97, Epoch time: 16.99
# Epoch: 425, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.99
# Epoch: 426, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.98
# Epoch: 427, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.01
# Epoch: 428, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.00
# Epoch: 429, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.00
# Epoch: 430, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.99
# Epoch: 431, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 432, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.01
# Epoch: 433, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.04
# Epoch: 434, Train acc: 99.39, Test acc: 99.24, Epoch time: 17.56
# Epoch: 435, Train acc: 99.99, Test acc: 99.92, Epoch time: 17.59
# Epoch: 436, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.15
# Epoch: 437, Train acc: 99.98, Test acc: 99.96, Epoch time: 17.12
# Epoch: 438, Train acc: 99.96, Test acc: 99.95, Epoch time: 17.09
# Epoch: 439, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.05
# Epoch: 440, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.04
# Epoch: 441, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.01
# Epoch: 442, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.01
# Epoch: 443, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.99
# Epoch: 444, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.02
# Epoch: 445, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.00
# Epoch: 446, Train acc: 99.96, Test acc: 99.93, Epoch time: 16.99
# Epoch: 447, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.00
# Epoch: 448, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.01
# Epoch: 449, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.99
# Epoch: 450, Train acc: 99.99, Test acc: 99.95, Epoch time: 16.99
# Epoch: 451, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.00
# Epoch: 452, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 453, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.00
# Epoch: 454, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.99
# Epoch: 455, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.01
# Epoch: 456, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.99
# Epoch: 457, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.98
# Epoch: 458, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.99
# Epoch: 459, Train acc: 98.82, Test acc: 98.83, Epoch time: 17.21
# Epoch: 460, Train acc: 99.93, Test acc: 99.87, Epoch time: 17.62
# Epoch: 461, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.26
# Epoch: 462, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.17
# Epoch: 463, Train acc: 99.98, Test acc: 99.95, Epoch time: 17.06
# Epoch: 464, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.06
# Epoch: 465, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.05
# Epoch: 466, Train acc: 99.97, Test acc: 99.93, Epoch time: 17.07
# Epoch: 467, Train acc: 99.98, Test acc: 99.94, Epoch time: 17.03
# Epoch: 468, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.04
# Epoch: 469, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.02
# Epoch: 470, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.01
# Epoch: 471, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.03
# Epoch: 472, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.07
# Epoch: 473, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.05
# Epoch: 474, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.00
# Epoch: 475, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.05
# Epoch: 476, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.00
# Epoch: 477, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.98
# Epoch: 478, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.96
# Epoch: 479, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.02
# Epoch: 480, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.96
# Epoch: 481, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.01
# Epoch: 482, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.00
# Epoch: 483, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.01
# Epoch: 484, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.99
# Epoch: 485, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.98
# Epoch: 486, Train acc: 99.99, Test acc: 99.95, Epoch time: 16.96
# Epoch: 487, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.97
# Epoch: 488, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 489, Train acc: 99.99, Test acc: 99.96, Epoch time: 16.99
# Epoch: 490, Train acc: 99.99, Test acc: 99.94, Epoch time: 16.98
# Epoch: 491, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 492, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.98
# Epoch: 493, Train acc: 100.00, Test acc: 99.95, Epoch time: 16.98
# Epoch: 494, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.99
# Epoch: 495, Train acc: 99.99, Test acc: 99.95, Epoch time: 16.98
# Epoch: 496, Train acc: 99.99, Test acc: 99.96, Epoch time: 16.99
# Epoch: 497, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.98
# Epoch: 498, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.99
# Epoch: 499, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.99
# Epoch: 500, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.00
# Epoch: 501, Train acc: 99.99, Test acc: 99.95, Epoch time: 16.98
# Epoch: 502, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.97
# Epoch: 503, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.97
# Epoch: 504, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.99
# Epoch: 505, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 506, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.97
# Epoch: 507, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.99
# Epoch: 508, Train acc: 99.98, Test acc: 99.95, Epoch time: 16.99
# Epoch: 509, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.97
# Epoch: 510, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.98
# Epoch: 511, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.97
# Epoch: 512, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.96
# Epoch: 513, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.97
# Epoch: 514, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.97
# Epoch: 515, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.00
# Epoch: 516, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.97
# Epoch: 517, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.96
# Epoch: 518, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.97
# Epoch: 519, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.98
# Epoch: 520, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.98
# Epoch: 521, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.00
# Epoch: 522, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.96
# Epoch: 523, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.98
# Epoch: 524, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.01
# Epoch: 525, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.98
# Epoch: 526, Train acc: 99.99, Test acc: 99.96, Epoch time: 16.99
# Epoch: 527, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.98
# Epoch: 528, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.97
# Epoch: 529, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.96
# Epoch: 530, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.95
# Epoch: 531, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.97
# Epoch: 532, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.97
# Epoch: 533, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.00
# Epoch: 534, Train acc: 99.99, Test acc: 99.98, Epoch time: 16.99
# Epoch: 535, Train acc: 99.98, Test acc: 99.95, Epoch time: 16.98
# Epoch: 536, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.97
# Epoch: 537, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.99
# Epoch: 538, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.98
# Epoch: 539, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.98
# Epoch: 540, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.99
# Epoch: 541, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.96
# Epoch: 542, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.99
# Epoch: 543, Train acc: 99.98, Test acc: 99.96, Epoch time: 16.99
# Epoch: 544, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 545, Train acc: 100.00, Test acc: 100.00, Epoch time: 16.98
# Epoch: 546, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.97
# Epoch: 547, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.96
# Epoch: 548, Train acc: 99.99, Test acc: 99.96, Epoch time: 16.98
# Epoch: 549, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.99
# Epoch: 550, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.98
# Epoch: 551, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.99
# Epoch: 552, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.95
# Epoch: 553, Train acc: 99.99, Test acc: 99.95, Epoch time: 16.99
# Epoch: 554, Train acc: 99.99, Test acc: 99.95, Epoch time: 16.97
# Epoch: 555, Train acc: 99.99, Test acc: 99.96, Epoch time: 16.98
# Epoch: 556, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.97
# Epoch: 557, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 558, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 559, Train acc: 99.52, Test acc: 99.50, Epoch time: 17.86
# Epoch: 560, Train acc: 99.65, Test acc: 99.46, Epoch time: 17.66
# Epoch: 561, Train acc: 99.98, Test acc: 99.93, Epoch time: 17.30
# Epoch: 562, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.14
# Epoch: 563, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.13
# Epoch: 564, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.06
# Epoch: 565, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.09
# Epoch: 566, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.06
# Epoch: 567, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.05
# Epoch: 568, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.04
# Epoch: 569, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.05
# Epoch: 570, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.04
# Epoch: 571, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.02
# Epoch: 572, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.05
# Epoch: 573, Train acc: 99.66, Test acc: 99.73, Epoch time: 17.32
# Epoch: 574, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.36
# Epoch: 575, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.15
# Epoch: 576, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.10
# Epoch: 577, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.04
# Epoch: 578, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.03
# Epoch: 579, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.06
# Epoch: 580, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.03
# Epoch: 581, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.02
# Epoch: 582, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.01
# Epoch: 583, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.03
# Epoch: 584, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.03
# Epoch: 585, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.04
# Epoch: 586, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.04
# Epoch: 587, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.05
# Epoch: 588, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.01
# Epoch: 589, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.00
# Epoch: 590, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.01
# Epoch: 591, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.02
# Epoch: 592, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.01
# Epoch: 593, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.01
# Epoch: 594, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.00
# Epoch: 595, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.00
# Epoch: 596, Train acc: 99.99, Test acc: 99.96, Epoch time: 16.99
# Epoch: 597, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.99
# Epoch: 598, Train acc: 99.99, Test acc: 99.97, Epoch time: 16.99
# Epoch: 599, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.00
# Epoch: 600, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 601, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.98
# Epoch: 602, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.98
# Epoch: 603, Train acc: 99.99, Test acc: 99.96, Epoch time: 16.98
# Epoch: 604, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.98
# Epoch: 605, Train acc: 100.00, Test acc: 99.99, Epoch time: 16.99
# Epoch: 606, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.01
# Epoch: 607, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.99
# Epoch: 608, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.00
# Epoch: 609, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.00
# Epoch: 610, Train acc: 100.00, Test acc: 100.00, Epoch time: 16.97
# Epoch: 611, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.98
# Epoch: 612, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.03
# Epoch: 613, Train acc: 100.00, Test acc: 99.96, Epoch time: 16.98
# Epoch: 614, Train acc: 99.99, Test acc: 99.94, Epoch time: 16.98
# Epoch: 615, Train acc: 100.00, Test acc: 99.98, Epoch time: 16.97
# Epoch: 616, Train acc: 99.99, Test acc: 99.93, Epoch time: 16.98
# Epoch: 617, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.04
# Epoch: 618, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.29
# Epoch: 619, Train acc: 100.00, Test acc: 99.97, Epoch time: 16.99
# Epoch: 620, Train acc: 99.98, Test acc: 99.95, Epoch time: 17.01
# Epoch: 621, Train acc: 99.98, Test acc: 99.95, Epoch time: 17.45
# Epoch: 622, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.47
# Epoch: 623, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.42
# Epoch: 624, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.43
# Epoch: 625, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.41
# Epoch: 626, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.42
# Epoch: 627, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.42
# Epoch: 628, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.41
# Epoch: 629, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.39
# Epoch: 630, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 631, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 632, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 633, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 634, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.44
# Epoch: 635, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.41
# Epoch: 636, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.42
# Epoch: 637, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.40
# Epoch: 638, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.40
# Epoch: 639, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.40
# Epoch: 640, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 641, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 642, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 643, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.39
# Epoch: 644, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.37
# Epoch: 645, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 646, Train acc: 96.96, Test acc: 97.16, Epoch time: 17.99
# Epoch: 647, Train acc: 99.99, Test acc: 100.00, Epoch time: 17.95
# Epoch: 648, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.62
# Epoch: 649, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.54
# Epoch: 650, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.55
# Epoch: 651, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.54
# Epoch: 652, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.47
# Epoch: 653, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.51
# Epoch: 654, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.48
# Epoch: 655, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.45
# Epoch: 656, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.44
# Epoch: 657, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.48
# Epoch: 658, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.45
# Epoch: 659, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.45
# Epoch: 660, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.42
# Epoch: 661, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.43
# Epoch: 662, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.41
# Epoch: 663, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.41
# Epoch: 664, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.42
# Epoch: 665, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.42
# Epoch: 666, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 667, Train acc: 99.98, Test acc: 99.95, Epoch time: 17.43
# Epoch: 668, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.43
# Epoch: 669, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.40
# Epoch: 670, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.41
# Epoch: 671, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.42
# Epoch: 672, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.42
# Epoch: 673, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.41
# Epoch: 674, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.42
# Epoch: 675, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.35
# Epoch: 676, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 677, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.39
# Epoch: 678, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.43
# Epoch: 679, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.41
# Epoch: 680, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.44
# Epoch: 681, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.43
# Epoch: 682, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.43
# Epoch: 683, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 684, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.40
# Epoch: 685, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.41
# Epoch: 686, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 687, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.36
# Epoch: 688, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.37
# Epoch: 689, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.39
# Epoch: 690, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.40
# Epoch: 691, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.38
# Epoch: 692, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.39
# Epoch: 693, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.39
# Epoch: 694, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 695, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 696, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.41
# Epoch: 697, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.40
# Epoch: 698, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 699, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.38
# Epoch: 700, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 701, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 702, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.37
# Epoch: 703, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 704, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.37
# Epoch: 705, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.39
# Epoch: 706, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.38
# Epoch: 707, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.38
# Epoch: 708, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 709, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 710, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.38
# Epoch: 711, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.39
# Epoch: 712, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.35
# Epoch: 713, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.37
# Epoch: 714, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.37
# Epoch: 715, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 716, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.36
# Epoch: 717, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 718, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.40
# Epoch: 719, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.40
# Epoch: 720, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.38
# Epoch: 721, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 722, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.40
# Epoch: 723, Train acc: 99.99, Test acc: 99.96, Epoch time: 17.40
# Epoch: 724, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.41
# Epoch: 725, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.39
# Epoch: 726, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.42
# Epoch: 727, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.40
# Epoch: 728, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.40
# Epoch: 729, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.42
# Epoch: 730, Train acc: 99.96, Test acc: 99.91, Epoch time: 17.40
# Epoch: 731, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.41
# Epoch: 732, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.36
# ...
# Epoch: 764, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 765, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.37
# Epoch: 766, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.43
# Epoch: 767, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.39
# Epoch: 768, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.41
# Epoch: 769, Train acc: 99.92, Test acc: 99.90, Epoch time: 17.39
# Epoch: 770, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.37
# Epoch: 771, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.37
# Epoch: 772, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 773, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.37
# Epoch: 774, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 775, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.37
# Epoch: 776, Train acc: 96.75, Test acc: 96.56, Epoch time: 17.56
# Epoch: 777, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.74
# Epoch: 778, Train acc: 99.98, Test acc: 99.97, Epoch time: 17.53
# Epoch: 779, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.44
# Epoch: 780, Train acc: 99.89, Test acc: 99.85, Epoch time: 17.46
# Epoch: 781, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.49
# Epoch: 782, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.45
# Epoch: 783, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.44
# Epoch: 784, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.46
# Epoch: 785, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.46
# Epoch: 786, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.43
# Epoch: 787, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.40
# Epoch: 788, Train acc: 99.98, Test acc: 99.98, Epoch time: 17.38
# Epoch: 789, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.36
# Epoch: 790, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 791, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 792, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 793, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.36
# Epoch: 794, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.37
# Epoch: 795, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.37
# Epoch: 796, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.38
# Epoch: 797, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.36
# Epoch: 798, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.35
# Epoch: 799, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.37
# Epoch: 800, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.36
# Epoch: 801, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 802, Train acc: 99.99, Test acc: 99.95, Epoch time: 17.37
# Epoch: 803, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.36
# Epoch: 804, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.37
# Epoch: 805, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.37
# Epoch: 806, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 807, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.35
# Epoch: 808, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 809, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.35
# Epoch: 810, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.36
# Epoch: 811, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.33
# Epoch: 812, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.35
# Epoch: 813, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.36
# Epoch: 814, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.37
# Epoch: 815, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.35
# Epoch: 816, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.39
# Epoch: 817, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.39
# Epoch: 818, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.34
# Epoch: 819, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.41
# Epoch: 820, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.37
# Epoch: 821, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.38
# Epoch: 822, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 823, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.36
# Epoch: 824, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.39
# Epoch: 825, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 826, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 827, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.40
# Epoch: 828, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 829, Train acc: 99.90, Test acc: 99.91, Epoch time: 18.97
# Epoch: 830, Train acc: 99.67, Test acc: 99.65, Epoch time: 17.85
# Epoch: 831, Train acc: 99.99, Test acc: 100.00, Epoch time: 17.67
# Epoch: 832, Train acc: 99.58, Test acc: 99.70, Epoch time: 17.64
# Epoch: 833, Train acc: 99.69, Test acc: 99.65, Epoch time: 17.72
# Epoch: 834, Train acc: 99.97, Test acc: 99.96, Epoch time: 17.58
# Epoch: 835, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.46
# Epoch: 836, Train acc: 99.91, Test acc: 99.89, Epoch time: 17.46
# Epoch: 837, Train acc: 99.98, Test acc: 99.97, Epoch time: 17.46
# Epoch: 838, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.45
# Epoch: 839, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.41
# Epoch: 840, Train acc: 99.97, Test acc: 99.98, Epoch time: 17.46
# Epoch: 841, Train acc: 99.98, Test acc: 99.97, Epoch time: 17.44
# Epoch: 842, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.44
# Epoch: 843, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.42
# Epoch: 844, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.43
# Epoch: 845, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.43
# Epoch: 846, Train acc: 99.99, Test acc: 99.99, Epoch time: 17.41
# Epoch: 847, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.44
# Epoch: 848, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.42
# Epoch: 849, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.42
# Epoch: 850, Train acc: 99.99, Test acc: 99.99, Epoch time: 17.41
# Epoch: 851, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 852, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.41
# Epoch: 853, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.37
# Epoch: 854, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 855, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 856, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.37
# Epoch: 857, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 858, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.36
# Epoch: 859, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 860, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 861, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.39
# Epoch: 862, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.40
# Epoch: 863, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.37
# Epoch: 864, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.39
# Epoch: 865, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 866, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.35
# Epoch: 867, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.37
# Epoch: 868, Train acc: 100.00, Test acc: 99.95, Epoch time: 17.37
# Epoch: 869, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.37
# Epoch: 870, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 871, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 872, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.40
# Epoch: 873, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.37
# Epoch: 874, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.40
# Epoch: 875, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 876, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.42
# Epoch: 877, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 878, Train acc: 99.96, Test acc: 99.95, Epoch time: 17.40
# Epoch: 879, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.37
# Epoch: 880, Train acc: 99.81, Test acc: 99.77, Epoch time: 17.94
# Epoch: 881, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.90
# Epoch: 882, Train acc: 99.92, Test acc: 99.91, Epoch time: 17.71
# Epoch: 883, Train acc: 99.90, Test acc: 99.87, Epoch time: 17.46
# Epoch: 884, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.50
# Epoch: 885, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.45
# Epoch: 886, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.52
# Epoch: 887, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.45
# Epoch: 888, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.41
# Epoch: 889, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.39
# Epoch: 890, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.44
# Epoch: 891, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.42
# Epoch: 892, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.43
# Epoch: 893, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.38
# Epoch: 894, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.38
# Epoch: 895, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.37
# Epoch: 896, Train acc: 99.99, Test acc: 99.99, Epoch time: 17.39
# Epoch: 897, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.39
# Epoch: 898, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.42
# Epoch: 899, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.41
# Epoch: 900, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.40
# Epoch: 901, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.41
# Epoch: 902, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.43
# Epoch: 903, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.41
# Epoch: 904, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.41
# Epoch: 905, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 906, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.40
# Epoch: 907, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 908, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 909, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.40
# Epoch: 910, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 911, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.41
# Epoch: 912, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 913, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 914, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.43
# Epoch: 915, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.40
# Epoch: 916, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 917, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.39
# Epoch: 918, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 919, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.37
# Epoch: 920, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.40
# Epoch: 921, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 922, Train acc: 99.99, Test acc: 99.98, Epoch time: 17.37
# Epoch: 923, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 924, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 925, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 926, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 927, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 928, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.38
# Epoch: 929, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 930, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 931, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.36
# Epoch: 932, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 933, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.37
# Epoch: 934, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.38
# Epoch: 935, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.36
# Epoch: 936, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.41
# Epoch: 937, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 938, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.38
# Epoch: 939, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 940, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.36
# Epoch: 941, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.39
# Epoch: 942, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.40
# Epoch: 943, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.35
# Epoch: 944, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.36
# Epoch: 945, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 946, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 947, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 948, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.52
# Epoch: 949, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 950, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.36
# Epoch: 951, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.40
# Epoch: 952, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.36
# Epoch: 953, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.51
# Epoch: 954, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.38
# Epoch: 955, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 956, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 957, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 958, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 959, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.38
# Epoch: 960, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.38
# Epoch: 961, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 962, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 963, Train acc: 99.99, Test acc: 99.97, Epoch time: 17.39
# Epoch: 964, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 965, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.39
# Epoch: 966, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 967, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.37
# Epoch: 968, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.35
# Epoch: 969, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.36
# Epoch: 970, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 971, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 972, Train acc: 100.00, Test acc: 99.97, Epoch time: 17.42
# Epoch: 973, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 974, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.42
# Epoch: 975, Train acc: 100.00, Test acc: 100.00, Epoch time: 17.38
# Epoch: 976, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.37
# Epoch: 977, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.39
# Epoch: 978, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 979, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 980, Train acc: 99.97, Test acc: 99.97, Epoch time: 17.38
# Epoch: 981, Train acc: 97.58, Test acc: 97.75, Epoch time: 17.43
# Epoch: 982, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.40
# Epoch: 983, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.36
# Epoch: 984, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 985, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.36
# Epoch: 986, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 987, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.35
# Epoch: 988, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 989, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.37
# Epoch: 990, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.37
# Epoch: 991, Train acc: 100.00, Test acc: 99.99, Epoch time: 17.37
# Epoch: 992, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.38
# Epoch: 993, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.35
# Epoch: 994, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.33
# Epoch: 995, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.35
# Epoch: 996, Train acc: 100.00, Test acc: 99.96, Epoch time: 17.33
# Epoch: 997, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.33
# Epoch: 998, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.34
# Epoch: 999, Train acc: 100.00, Test acc: 99.98, Epoch time: 17.36
# [[430  90]
#  [117 290]
#  [333  39]
#  [221 264]
#  [423 210]
#  [303 140]
#  [249   1]
#  [ 94 123]
#  [ 13 158]
#  [320  61]
#  [490 317]
#  [308 137]
#  [119 442]
#  [ 11 497]
#  [197 109]
#  [385 184]
#  [206 382]
#  [485  42]
#  [120 427]
#  [  7 397]
#  [ 61 207]
#  [280 320]
#  [261 293]
#  [ 70  45]
#  [163 357]]
# [[   0 1021]
#  [   1 1020]
#  [   2 1019]
#  ...
#  [ 413  587]
#  [ 414  586]
#  [ 415  585]]
# {'Plain': 0, 'Red': 1, 'Blue': 2}

# %%
import numpy as np
import matplotlib.pyplot as plt

def moving_average(data, window_size=10):
    return [np.mean(data[i:i+window_size]) for i in range(0, len(data), window_size)]

train_acc_smooth = moving_average(train_acc, window_size=10)
test_acc_smooth = moving_average(test_acc, window_size=10)

epoch_list_smooth = epoch_list[9::10]

plt.figure(figsize=(12, 6))

plt.plot(epoch_list_smooth, train_acc_smooth, label="Train accuracy", marker='o', linestyle='--')
plt.plot(epoch_list_smooth, test_acc_smooth, label="Test accuracy", marker='o', linestyle='-')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy for predictions of Hex game')

plt.legend(loc=5)

parameters_text = f"Board size: {board_size}x{board_size}\nDataset size: {len(dataset)}\nClauses: {args.number_of_clauses}\nT: {args.T}\ns: {args.s}\nDepth: {args.depth}\nHypervector Size: {args.hypervector_size}\nHypervector bits: {args.hypervector_bits}\nMessage Size: {args.message_size}\nMessage bits: {args.message_bits}\nLiterals: {args.max_included_literals}"
plt.text(0.91, 0.02, parameters_text, transform=plt.gca().transAxes, fontsize=10,
         ha='center', bbox=dict(facecolor='white', alpha=0.5))

plt.grid(True)
plt.savefig('hex_game_8x8-new2bf5.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Trim data to the first 500 epochs
max_epochs = 400
train_acc = train_acc[:max_epochs]
test_acc = test_acc[:max_epochs]
epoch_list = epoch_list[:max_epochs]

# Define moving average
def moving_average(data, window_size=10):
    return [np.mean(data[i:i+window_size]) for i in range(0, len(data) - window_size + 1, window_size)]

# Apply moving average
window_size = 10
train_acc_smooth = moving_average(train_acc, window_size=window_size)
test_acc_smooth = moving_average(test_acc, window_size=window_size)

# Generate corresponding epoch_list_smooth
epoch_list_smooth = epoch_list[window_size - 1::window_size]

# Plot
plt.figure(figsize=(12, 6))

plt.plot(epoch_list_smooth, train_acc_smooth, label="Train accuracy", marker='o', linestyle='--')
plt.plot(epoch_list_smooth, test_acc_smooth, label="Test accuracy", marker='o', linestyle='-')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy for predictions of Hex game')

plt.legend(loc=5)

parameters_text = f"Board size: {board_size}x{board_size}\nDataset size: {len(dataset)}\nClauses: {args.number_of_clauses}\nT: {args.T}\ns: {args.s}\nDepth: {args.depth}\nHypervector Size: {args.hypervector_size}\nHypervector bits: {args.hypervector_bits}\nMessage Size: {args.message_size}\nMessage bits: {args.message_bits}\nLiterals: {args.max_included_literals}"
plt.text(0.91, 0.02, parameters_text, transform=plt.gca().transAxes, fontsize=10,
         ha='center', bbox=dict(facecolor='white', alpha=0.5))

plt.grid(True)
plt.savefig('hex_game_8x8-new2bf5.png')
plt.show()
